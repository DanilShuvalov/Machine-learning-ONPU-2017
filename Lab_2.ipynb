# %%
import graphlab

# %% [markdown]
# 1. Запускаем Graphlab. Создаем SFrame на основе файла с тестовыми данными people.csv.

# %%
sf = graphlab.SFrame('people.csv')
sf
# Out:
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: C:\Users\dansh\AppData\Local\Temp\graphlab_server_1511697907.log.0
# This non-commercial license of GraphLab Create for academic use is assigned to danil_shuvalov@ukr.net and will expire on November 26, 2018.
# Finished parsing file C:\Users\dansh\people.csv
# Parsing completed. Parsed 56 lines in 0.010005 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str,str,long]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file C:\Users\dansh\people.csv
# Parsing completed. Parsed 56 lines in 0.018048 secs.
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
#
# Rows: 56
#
# Data:
# ...

# %%
import numpy as np
sf['Номер дома']=np.random.randint(1,150)

# %%
sf
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	Номер дома	int
#
# Rows: 56
#
# Data:
# +-----------+-----------+-----------+---------+---------+------------+
# |    Имя    |  Фамилия  |   Город   |  Страна | Возраст | Номер дома |
# +-----------+-----------+-----------+---------+---------+------------+
# |   Семен   |  Мельник  |   Чикаго  |   США   |    24   |    112     |
# |   Елена   |   Бойко   |   Квебек  |  Канада |    23   |    112     |
# | Екатерина | Коваленко | Манчестер |  Англия |    45   |    112     |
# | Александр |   Шевчук  | Вашингтон |   США   |    23   |    112     |
# |    Иван   |  Олейник  |    Киев   | Украина |    23   |    112     |
# |   София   | Коваленко |    Киев   | Украина |    22   |    112     |
# |  Николай  |  Семенов  | Стокгольм |  Швеция |    25   |    112     |
# |   Елена   |   Бойко   |   Квебек  |  Канада |    23   |    112     |
# | Екатерина | Коваленко | Манчестер |  Англия |    22   |    112     |
# ...

# %% [markdown]
# 2. Подключаем библиотеку numpy.Создаем новый столбец с именем "Номер дома". Используя функцию numpy.random.randint() заполняем столбец псевдо-случайными значениями в диапазоне [1, 150).

# %%
sf['ФИО']= sf['Фамилия']+ '  ' +sf['Имя']
sf
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	Номер дома	int
# 	ФИО	str
#
# Rows: 56
#
# Data:
# +-----------+-----------+-----------+---------+---------+------------+
# |    Имя    |  Фамилия  |   Город   |  Страна | Возраст | Номер дома |
# +-----------+-----------+-----------+---------+---------+------------+
# |   Семен   |  Мельник  |   Чикаго  |   США   |    24   |    112     |
# |   Елена   |   Бойко   |   Квебек  |  Канада |    23   |    112     |
# | Екатерина | Коваленко | Манчестер |  Англия |    45   |    112     |
# | Александр |   Шевчук  | Вашингтон |   США   |    23   |    112     |
# |    Иван   |  Олейник  |    Киев   | Украина |    23   |    112     |
# |   София   | Коваленко |    Киев   | Украина |    22   |    112     |
# |  Николай  |  Семенов  | Стокгольм |  Швеция |    25   |    112     |
# |   Елена   |   Бойко   |   Квебек  |  Канада |    23   |    112     |
# ...

# %% [markdown]
# 3. Используя логический фильтр, выводим все строки, в которых:
# 'ФИО' = 'Семенов Семен'И 'Возраст' != 24

# %%
sf[(sf['ФИО'] == 'Семенов  Семен') & (sf['Возраст'] != 24)]
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	Номер дома	int
# 	ФИО	str
#
# Rows: Unknown
#
# Data:
# +-------+---------+-----------+--------+---------+------------+
# |  Имя  | Фамилия |   Город   | Страна | Возраст | Номер дома |
# +-------+---------+-----------+--------+---------+------------+
# | Семен | Семенов | Стокгольм | Швеция |    25   |    112     |
# | Семен | Семенов | Стокгольм | Швеция |    25   |    112     |
# | Семен | Семенов | Стокгольм | Швеция |    25   |    112     |
# | Семен | Семенов | Стокгольм | Швеция |    25   |    112     |
# | Семен | Семенов | Стокгольм | Швеция |    25   |    112     |
# | Семен | Семенов | Вашингтон |  США   |    25   |    112     |
# +-------+---------+-----------+--------+---------+------------+
# +----------------+
# |      ФИО       |
# +----------------+
# | Семенов  Семен |
# | Семенов  Семен |
# | Семенов  Семен |
# | Семенов  Семен |
# | Семенов  Семен |
# | Семенов  Семен |
# ...

# %% [markdown]
# 4. Используя логический фильтр, выводим все строки, в которых:
# 'Страна' = 'США'И 'Возраст' != 24

# %%
sf[(sf['Страна'] == 'США') & (sf['Возраст'] != 24)]
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	Номер дома	int
# 	ФИО	str
#
# Rows: Unknown
#
# Data:
# +-----------+---------+-----------+--------+---------+------------+
# |    Имя    | Фамилия |   Город   | Страна | Возраст | Номер дома |
# +-----------+---------+-----------+--------+---------+------------+
# | Александр |  Шевчук | Вашингтон |  США   |    23   |    112     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |    112     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |    112     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |    112     |
# | Александр |  Шевчук |   Чикаго  |  США   |    23   |    112     |
# | Александр |  Шевчук |   Чикаго  |  США   |    23   |    112     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |    112     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |    112     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |    112     |
# ...
